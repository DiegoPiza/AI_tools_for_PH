# %%
Importing libraries

# %%
# !pip install bs4
# !pip install selenium
# !pip install pandas
# !pip install html5lib
# !pip install matplotlib
# !pip install scikit-learn
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------------ --------------------- 4.5/9.5 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 35.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 11.6/11.6 MB 72.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 12.9/12.9 MB 89.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 8.0/8.0 MB 98.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 121.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 73.9 MB/s eta 0:00:00
# ...
